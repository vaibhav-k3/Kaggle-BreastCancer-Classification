# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Importing csv and viewing data

# %%
data = pd.read_csv('data.csv')
data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
data.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
data.columns
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst', 'Unnamed: 32'],
#       dtype='object')

# %% [markdown]
# # Visualizing Data to establish relationships , and selecting features for further predictions

# %%
pairgrid = sns.PairGrid(data , x_vars = 'diagnosis' , y_vars = ['area_mean', 'texture_mean', 'compactness_mean','concavity_mean','symmetry_mean', 'concave points_mean'])
pairgrid.map(sns.barplot , palette = 'spring')

# %%
sns.PairGrid?

# %%
pairgrid = sns.PairGrid(data , vars = ['area_mean','concave points_mean' ,'smoothness_mean', 'compactness_mean','concavity_mean','symmetry_mean'] , hue= 'diagnosis')
pairgrid = pairgrid.map(sns.scatterplot)
pairgrid.add_legend()

# %%
X_data = data[['area_mean','concave points_mean','texture_mean','compactness_mean','concavity_mean']]
#X_data.loc[:,'area_mean'] = (X_data.loc[:,'area_mean'] - np.mean(X_data['area_mean']))/np.max(X_data['area_mean'])
#X_data.loc[:,'concave points_mean'] = (X_data.loc[:,'concave points_mean'] - np.mean(X_data['concave points_mean']))/np.max(X_data['concave points_mean'])
#X_data.loc[:,'texture_mean'] = (X_data.loc[:,'texture_mean'] - np.mean(X_data['texture_mean']))/np.max(X_data['texture_mean'])
#X_data.loc[:,'compactness_mean'] = (X_data.loc[:,'compactness_mean'] - np.mean(X_data['compactness_mean']))/np.max(X_data['compactness_mean'])
#X_data.loc[:,'concavity_mean'] = (X_data.loc[:,'concavity_mean'] - np.mean(X_data['concavity_mean']))/np.max(X_data['concavity_mean'])
Y_data = pd.DataFrame(index= data.index , columns = ['M'])
for col in X_data.columns:
    X_data.loc[:,col] = (X_data.loc[:,col] - np.mean(X_data[col]))/np.max(X_data[col])
    
for i in Y_data.index:
    if data.loc[i , 'diagnosis'] == 'M':
        Y_data.loc[i,'M'] = 1
    else:
        Y_data.loc[i , 'M'] = 0
        
X_data.head()

#not able to resolve this warning
# Out:
# C:\Users\Vaibhav\Anaconda3\lib\site-packages\pandas\core\indexing.py:630: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item_labels[indexer[info_axis]]] = value
#    area_mean  concave points_mean  texture_mean  compactness_mean  \
# 0   0.138389             0.487976     -0.226824          0.501618
# 1   0.268337             0.105621     -0.038688         -0.074409
# 2   0.219157             0.392549      0.049907          0.160854
# 3  -0.107473             0.279726      0.027758          0.519858
# 4   0.256742             0.275253     -0.126009          0.082394
#
#    concavity_mean
# 0        0.495081
# 1       -0.004450
# 2        0.254453
# 3        0.357546
# 4        0.255859

# %%
X_train , X_test , Y_train , Y_test = train_test_split(X_data , Y_data , test_size = 0.2)

# %%
for k in range(1,15):
    Knnmodel = KNeighborsClassifier(n_neighbors = k , weights = 'uniform')
    Knnmodel.fit(np.array(X_train) , np.array(Y_train).ravel()) ## the ravel function flattens the array
    #what ravel() does is: when you have y.shape == (10, 1), using y.ravel().shape == (10, ). In words... it flattens an array.
    #x=Knnmodel.score(X_test , Y_test)
    x = 0
    for i in Y_test.index:
        if Knnmodel.predict(np.array(X_test.loc[i]).reshape(1,-1))== Y_test.loc[i , 'M']:
            x = x +1
    x = (x/len(Y_test))
    print('k = '+str(k) + '-->' + str(x))
# Out:
# k = 1-->0.9473684210526315
# k = 2-->0.9385964912280702
# k = 3-->0.9473684210526315
# k = 4-->0.9473684210526315
# k = 5-->0.9473684210526315
# k = 6-->0.9473684210526315
# k = 7-->0.956140350877193
# k = 8-->0.956140350877193
# k = 9-->0.9473684210526315
# k = 10-->0.9473684210526315
# k = 11-->0.956140350877193
# k = 12-->0.956140350877193
# k = 13-->0.956140350877193
# k = 14-->0.956140350877193

# %%
X_test.loc[90]
# Out:
# area_mean              0.003123
# concave points_mean   -0.096169
# texture_mean           0.120426
# compactness_mean      -0.052927
# concavity_mean        -0.135378
# Name: 90, dtype: float64
